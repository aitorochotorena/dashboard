# %%
import pyEX as p
p.companyDF('aapl')
# Out:
#                     CEO companyName  \
# symbol
# AAPL    Timothy D. Cook  Apple Inc.
#
#                                               description  \
# symbol
# AAPL    Apple Inc is designs, manufactures and markets...
#
#                     exchange           industry issueType      sector  \
# symbol
# AAPL    Nasdaq Global Select  Computer Hardware        cs  Technology
#
#                                                      tags  \
# symbol
# AAPL    [Technology, Consumer Electronics, Computer Ha...
#
#                      website
# symbol
# AAPL    http://www.apple.com

# %%
# %matplotlib inline
p.chartDF('aapl')[['open', 'high', 'low', 'close']].plot(kind='line')

# %%
import pyEXstudies as ps

# %%
import seaborn as sns
corr = ps.peerCorrelation('aapl')
sns.heatmap(corr, 
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values)
